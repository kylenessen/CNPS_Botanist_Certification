# %% [markdown]
# # Plant List Flashcards
#
# The purpose of this notebook is to take David's list of 500 plants and turn them into anki cards to study.
#
# I have already cleaned this list manually in excel. Specifically I have:
#
# 1. Resolved synonyms, or removed duplicate genus names from the table. I matched to current CalFlora.
# 2. Fixed minor issues with ssp. vs spp.
# 3. Translated acronyms for habit descriptions
# 4. Made native vs non-native explicit
# 5. Indicate with a boolean if genus or full scientific name is required
#
# I could have done it in this notebook, but honestly I think it was faster to just go through the document.
#
# Now to be fair, I have not verified *each name.* There is definitely the possiblity that some of the names won't match whatver taxonomy I choose to use.
#
# As for the flash cards, I want to present a photo, preferably the "iconic" photo from inaturalist for the taxa, and then ask for the either the full scientific name, or just the genus. The flip side of the card will be the name. Bonus points if it has to be typed out.

# %%
import pandas as pd

df = pd.read_excel('CommonPlantsBotanistMustSightID-Alphabetic-20191009.xlsx')
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Scientific Name              Common Name  \
# 0          Abies concolor     California White Fir
# 1         Abies magnifica                  Red Fir
# 2            Abronia spp.             Sand-verbena
# 3         Acacia dealbata            Silver Wattle
# 4            Acer glabrum     Rocky Mountain Maple
# ..                    ...                      ...
# 496  Washingtonia robusta         Mexican Fan Palm
# 497  Woodwardia fimbriata         Giant Chain Fern
# 498          Wyethia spp.                Mule Ears
# 499         Xanthium spp.  Spiny or Spring Clotbur
# 500      Yucca brevifolia              Joshua Tree
#
#                         HabiTree         Family  Genus Only    Nativity
# 0                           Tree       Pinaceae       False      Native
# 1                           Tree       Pinaceae       False      Native
# 2                 Perennial herb  Nyctaginaceae        True      Native
# 3                     Shrub/Tree       Fabaceae       False  Non-native
# 4                          Shrub    Sapindaceae       False      Native
# ..                           ...            ...         ...         ...
# 496                         Tree      Arecaceae       False  Non-native
# 497  Perennial fern or fern ally    Blechnaceae       False      Native
# 498               Perennial herb     Asteraceae        True      Native
# 499                  Annual herb     Asteraceae        True      Native
# 500                         Tree      Agavaceae       False      Native
#
# [501 rows x 6 columns]

# %% [markdown]
# Let's check the data types and make any changes necessary.

# %%
df.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Scientific Name    object
# Common Name        object
# HabiTree           object
# Family             object
# Genus Only           bool
# Nativity           object
# dtype: object

# %% [markdown]
# Looks good! Now let's get the url from inaturalist

# %%
from pyinaturalist import *

url = get_taxa('Xanthium')['results'][0]['default_photo']['medium_url']
url = url.replace('medium', 'large')
url
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'https://inaturalist-open-data.s3.amazonaws.com/photos/12627/large.jpg'

# %% [markdown]
# It looks like having "spp." in the name throws off the query. So in the following code I will simply remove that and have clean genus names only.

# %%
# remove "spp." from the end of genus names in df
df['Search Name'] = df['Scientific Name']
df['Search Name'] = df['Search Name'].str.replace('spp.', '')
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Scientific Name              Common Name  \
# 0          Abies concolor     California White Fir
# 1         Abies magnifica                  Red Fir
# 2            Abronia spp.             Sand-verbena
# 3         Acacia dealbata            Silver Wattle
# 4            Acer glabrum     Rocky Mountain Maple
# ..                    ...                      ...
# 496  Washingtonia robusta         Mexican Fan Palm
# 497  Woodwardia fimbriata         Giant Chain Fern
# 498          Wyethia spp.                Mule Ears
# 499         Xanthium spp.  Spiny or Spring Clotbur
# 500      Yucca brevifolia              Joshua Tree
#
#                         HabiTree         Family  Genus Only    Nativity  \
# 0                           Tree       Pinaceae       False      Native
# 1                           Tree       Pinaceae       False      Native
# 2                 Perennial herb  Nyctaginaceae        True      Native
# 3                     Shrub/Tree       Fabaceae       False  Non-native
# 4                          Shrub    Sapindaceae       False      Native
# ..                           ...            ...         ...         ...
# 496                         Tree      Arecaceae       False  Non-native
# 497  Perennial fern or fern ally    Blechnaceae       False      Native
# 498               Perennial herb     Asteraceae        True      Native
# 499                  Annual herb     Asteraceae        True      Native
# 500                         Tree      Agavaceae       False      Native
#
#               Search Name
# 0          Abies concolor
# 1         Abies magnifica
# 2                Abronia
# 3         Acacia dealbata
# 4            Acer glabrum
# ..                    ...
# 496  Washingtonia robusta
# 497  Woodwardia fimbriata
# 498              Wyethia
# 499             Xanthium
# 500      Yucca brevifolia
#
# [501 rows x 7 columns]

# %% [markdown]
# Let's test to see if I can get rid of the "ssp." as well. I doubt it, but would love to.

# %%
# filter rows that contain "ssp." in the Scientific Name column
df[df['Search Name'].str.contains("ssp.")]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Scientific Name, Common Name, HabiTree, Family, Genus Only, Nativity, Search Name]
# Index: []

# %%
get_taxa('Sambucus nigra caerulea')['results'][0]['default_photo']['medium_url']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'https://inaturalist-open-data.s3.amazonaws.com/photos/46738687/medium.jpg'

# %% [markdown]
# Bless the inaturalist folks, they don't like ssp either!
#
# Looks like I can safely remove that as well.

# %%
df['Search Name'] = df['Search Name'].str.replace('ssp.', '')
df['Search Name'] = df['Search Name'].str.replace('var.', '')
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Scientific Name              Common Name  \
# 0          Abies concolor     California White Fir
# 1         Abies magnifica                  Red Fir
# 2            Abronia spp.             Sand-verbena
# 3         Acacia dealbata            Silver Wattle
# 4            Acer glabrum     Rocky Mountain Maple
# ..                    ...                      ...
# 496  Washingtonia robusta         Mexican Fan Palm
# 497  Woodwardia fimbriata         Giant Chain Fern
# 498          Wyethia spp.                Mule Ears
# 499         Xanthium spp.  Spiny or Spring Clotbur
# 500      Yucca brevifolia              Joshua Tree
#
#                         HabiTree         Family  Genus Only    Nativity  \
# 0                           Tree       Pinaceae       False      Native
# 1                           Tree       Pinaceae       False      Native
# 2                 Perennial herb  Nyctaginaceae        True      Native
# 3                     Shrub/Tree       Fabaceae       False  Non-native
# 4                          Shrub    Sapindaceae       False      Native
# ..                           ...            ...         ...         ...
# 496                         Tree      Arecaceae       False  Non-native
# 497  Perennial fern or fern ally    Blechnaceae       False      Native
# 498               Perennial herb     Asteraceae        True      Native
# 499                  Annual herb     Asteraceae        True      Native
# 500                         Tree      Agavaceae       False      Native
#
#               Search Name
# 0          Abies concolor
# 1         Abies magnifica
# 2                Abronia
# 3         Acacia dealbata
# 4            Acer glabrum
# ..                    ...
# 496  Washingtonia robusta
# 497  Woodwardia fimbriata
# 498              Wyethia
# 499             Xanthium
# 500      Yucca brevifolia
#
# [501 rows x 7 columns]

# %% [markdown]
# Great, now that's sorted, let's generate the photo url column.

# %%
df['Search Name'] = df['Search Name'].str.strip()
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Scientific Name              Common Name  \
# 0          Abies concolor     California White Fir
# 1         Abies magnifica                  Red Fir
# 2            Abronia spp.             Sand-verbena
# 3         Acacia dealbata            Silver Wattle
# 4            Acer glabrum     Rocky Mountain Maple
# ..                    ...                      ...
# 496  Washingtonia robusta         Mexican Fan Palm
# 497  Woodwardia fimbriata         Giant Chain Fern
# 498          Wyethia spp.                Mule Ears
# 499         Xanthium spp.  Spiny or Spring Clotbur
# 500      Yucca brevifolia              Joshua Tree
#
#                         HabiTree         Family  Genus Only    Nativity  \
# 0                           Tree       Pinaceae       False      Native
# 1                           Tree       Pinaceae       False      Native
# 2                 Perennial herb  Nyctaginaceae        True      Native
# 3                     Shrub/Tree       Fabaceae       False  Non-native
# 4                          Shrub    Sapindaceae       False      Native
# ..                           ...            ...         ...         ...
# 496                         Tree      Arecaceae       False  Non-native
# 497  Perennial fern or fern ally    Blechnaceae       False      Native
# 498               Perennial herb     Asteraceae        True      Native
# 499                  Annual herb     Asteraceae        True      Native
# 500                         Tree      Agavaceae       False      Native
#
#               Search Name
# 0          Abies concolor
# 1         Abies magnifica
# 2                 Abronia
# 3         Acacia dealbata
# 4            Acer glabrum
# ..                    ...
# 496  Washingtonia robusta
# 497  Woodwardia fimbriata
# 498               Wyethia
# 499              Xanthium
# 500      Yucca brevifolia
#
# [501 rows x 7 columns]

# %%
from pyinaturalist import *
# function to look up the default photo for each taxa on inaturalist and convert to the large format.
def get_default_photo(scientific_name):
    try:
        url = get_taxa(scientific_name)['results'][0]['default_photo']['medium_url']
        #url = url.replace('medium', 'large')
        return url
    except Exception:
        return None

# apply the function to the taxa dataframe

df['photo_url'] = df['Search Name'].apply(get_default_photo)

# %%
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Scientific Name           Common Name        HabiTree         Family  \
# 0   Abies concolor  California White Fir            Tree       Pinaceae
# 1  Abies magnifica               Red Fir            Tree       Pinaceae
# 2     Abronia spp.          Sand-verbena  Perennial herb  Nyctaginaceae
# 3  Acacia dealbata         Silver Wattle      Shrub/Tree       Fabaceae
# 4     Acer glabrum  Rocky Mountain Maple           Shrub    Sapindaceae
#
#    Genus Only    Nativity      Search Name  \
# 0       False      Native   Abies concolor
# 1       False      Native  Abies magnifica
# 2        True      Native          Abronia
# 3       False  Non-native  Acacia dealbata
# 4       False      Native     Acer glabrum
#
#                                            photo_url
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://static.inaturalist.org/photos/86547995...
# 2  https://inaturalist-open-data.s3.amazonaws.com...
# 3  https://static.inaturalist.org/photos/12773260...
# 4  https://inaturalist-open-data.s3.amazonaws.com...

# %%
df[df['photo_url'].isnull()]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                         Scientific Name               Common Name  \
# 6                          Acer negundo                 Box Elder
# 90  Castilleja applegatei ssp. martinii  Martin Indian Paintbrush
#
#           HabiTree         Family  Genus Only Nativity  \
# 6       Shrub/Tree    Sapindaceae       False   Native
# 90  Perennial herb  Orobanchaceae       False   Native
#
#                         Search Name photo_url
# 6                      Acer negundo      None
# 90  Castilleja applegatei  martinii      None

# %%
import os
import requests
from tqdm import tqdm

# Directory to save images
img_dir = 'plant_images/'
if not os.path.exists(img_dir):
    os.makedirs(img_dir)

# Function to download image
def download_image(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as file:
            file.write(response.content)
# Retry the image downloading process

# Loop through dataframe and download images
local_paths = []
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    if pd.notna(row['photo_url']):
        local_path = os.path.join(img_dir, row['Scientific Name'].replace(' ', '_') + '.jpg')
        try:
            download_image(row['photo_url'], local_path)
            local_paths.append(local_path)
        except:
            local_paths.append(None)
    else:
        local_paths.append(None)

df['local_photo_path'] = local_paths
df
# Out:
# 100%|██████████| 501/501 [05:07<00:00,  1.63it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Scientific Name              Common Name  \
# 0          Abies concolor     California White Fir
# 1         Abies magnifica                  Red Fir
# 2            Abronia spp.             Sand-verbena
# 3         Acacia dealbata            Silver Wattle
# 4            Acer glabrum     Rocky Mountain Maple
# ..                    ...                      ...
# 496  Washingtonia robusta         Mexican Fan Palm
# 497  Woodwardia fimbriata         Giant Chain Fern
# 498          Wyethia spp.                Mule Ears
# 499         Xanthium spp.  Spiny or Spring Clotbur
# 500      Yucca brevifolia              Joshua Tree
#
#                         HabiTree         Family  Genus Only    Nativity  \
# 0                           Tree       Pinaceae       False      Native
# 1                           Tree       Pinaceae       False      Native
# 2                 Perennial herb  Nyctaginaceae        True      Native
# 3                     Shrub/Tree       Fabaceae       False  Non-native
# 4                          Shrub    Sapindaceae       False      Native
# ..                           ...            ...         ...         ...
# 496                         Tree      Arecaceae       False  Non-native
# 497  Perennial fern or fern ally    Blechnaceae       False      Native
# 498               Perennial herb     Asteraceae        True      Native
# 499                  Annual herb     Asteraceae        True      Native
# 500                         Tree      Agavaceae       False      Native
#
#               Search Name                                          photo_url  \
# 0          Abies concolor  https://inaturalist-open-data.s3.amazonaws.com...
# 1         Abies magnifica  https://static.inaturalist.org/photos/86547995...
# 2                 Abronia  https://inaturalist-open-data.s3.amazonaws.com...
# 3         Acacia dealbata  https://static.inaturalist.org/photos/12773260...
# 4            Acer glabrum  https://inaturalist-open-data.s3.amazonaws.com...
# ..                    ...                                                ...
# 496  Washingtonia robusta  https://inaturalist-open-data.s3.amazonaws.com...
# 497  Woodwardia fimbriata  https://inaturalist-open-data.s3.amazonaws.com...
# 498               Wyethia  https://inaturalist-open-data.s3.amazonaws.com...
# 499              Xanthium  https://inaturalist-open-data.s3.amazonaws.com...
# 500      Yucca brevifolia  https://static.inaturalist.org/photos/26295527...
#
#                           local_photo_path
# 0          plant_images/Abies_concolor.jpg
# 1         plant_images/Abies_magnifica.jpg
# 2            plant_images/Abronia_spp..jpg
# 3         plant_images/Acacia_dealbata.jpg
# 4            plant_images/Acer_glabrum.jpg
# ..                                     ...
# 496  plant_images/Washingtonia_robusta.jpg
# 497  plant_images/Woodwardia_fimbriata.jpg
# 498          plant_images/Wyethia_spp..jpg
# 499         plant_images/Xanthium_spp..jpg
# 500      plant_images/Yucca_brevifolia.jpg
#
# [501 rows x 9 columns]

# %%
# Function to create the front of the card based on "Genus Only" column and image path
def create_front(row):
    question = "What is the genus of this plant?" if row["Genus Only"] else "What is the scientific name of this plant?"
    if pd.notna(row["local_photo_path"]):
        return f'<img src="{row["local_photo_path"]}"><br>{question}'
    else:
        return question

# Construct the Anki card format
df["Front"] = df.apply(create_front, axis=1)
df["Back"] = df["Scientific Name"]

# Save as a CSV
anki_csv_path = "anki_flashcards.csv"
df[["Front", "Back"]].to_csv(anki_csv_path, index=False, sep=";")

anki_csv_path
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'anki_flashcards.csv'
